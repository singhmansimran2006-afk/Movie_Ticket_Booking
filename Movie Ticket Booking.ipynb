# %%
age = int (input("Enter your age :"))
ticket = True
if age > 18:
    print ("You can watch the movie")
    if age > 18:
            print ("Show your ID")
    if ticket == True:
        print("You can go inside")
elif age < 15:
    print ("You can watch the movie with your parents")
else:
    print ("Not allowed")
# Out:
# Enter your age : 14
# You can watch the movie with your parents
